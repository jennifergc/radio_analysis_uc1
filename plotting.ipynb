# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS
from scipy.signal import find_peaks
from scipy.optimize import curve_fit

# %%
import sys
sys.path.append('/home/jennifer/fits_plotting_tool')  # Agrega el directorio donde está fits_plotter.py

from fits_plotter import FITSPlotter

# %%
# Ruta del archivo FITS
fits_file = "/home/jennifer/casa/M17_p2015/ALMB00058836_CONTINUO.fits"

# %%
# Crear instancia de FITSPlotter
plotter = FITSPlotter(image_fits=fits_file)

# Graficar la imagen sin contornos
plotter.plot()

# Cerrar archivos FITS
plotter.close()
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57648.029713 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -67.754929 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -23.022886 from OBSGEO-[XYZ].
# Set OBSGEO-H to     5053.796 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Archivos FITS cerrados.

# %%
#En la región 

from regions import Regions

# %%
region_file = "/home/jennifer/casa/M17_p2015/target2_region1.crtf"

# %%
# Leer archivo CRTF y extraer regiones
regions = Regions.read(region_file, format="crtf")

# %% [raw]
# # Cargar y graficar la imagen
# plotter = FITSPlotter(image_fits=fits_file)
# plotter.plot()  # Graficar imagen
#
# # Obtener el eje actual después de graficar
# ax = plt.gca()
#
# # Leer archivo CRTF y extraer regiones
# regions = Regions.read(region_file, format="crtf")
#
# # Dibujar la región en la imagen y calcular límites para hacer zoom
# x_min, x_max, y_min, y_max = np.inf, -np.inf, np.inf, -np.inf
#
# for region in regions:
#     pixel_region = region.to_pixel(plotter.wcs_base)  # Convertir a coordenadas de píxeles
#     pixel_region.plot(ax=ax, color='red', linewidth=1.5)
#
#     # Obtener los límites de la región
#     bbox = pixel_region.bounding_box
#     x_min, x_max = min(x_min, bbox.ixmin), max(x_max, bbox.ixmax)
#     y_min, y_max = min(y_min, bbox.iymin), max(y_max, bbox.iymax)
#
# # Ajustar los ejes para hacer zoom en la región
# ax.set_xlim(x_min - 10, x_max + 10)  # Pequeño margen extra
# ax.set_ylim(y_min - 10, y_max + 10)
# plt.show()
#
# # Cerrar archivos FITS
# plotter.close()

# %%
#PRUEBA CON EL NUEVO FITS PLOTTER

import sys
sys.path.append('prueba1.py')  # Agrega el directorio donde está fits_plotter.py

from prueba1 import FITSPlotter

# %%
fits_file = "/home/jennifer/casa/M17_p2015/ALMB00058836_CONTINUO.fits"

plotter = FITSPlotter(image_fits=fits_file)
plotter.plot()
plotter.close()
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57648.029713 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -67.754929 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -23.022886 from OBSGEO-[XYZ].
# Set OBSGEO-H to     5053.796 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Archivos FITS cerrados.

# %%
from fits_plotter import FITSPlotter

# Ruta del archivo FITS y el archivo de la región CRTF
fits_file = "/home/jennifer/casa/M17_p2015/ALMB00058836_CONTINUO.fits"
region_file = "/home/jennifer/casa/M17_p2015/target2_region1.crtf"

# Crear instancia de FITSPlotter con la región CRTF
plotter = FITSPlotter(image_fits=fits_file, region_file=region_file)

# Graficar la imagen recortada a la región del CRTF
plotter.plot()

# Cerrar archivos FITS
plotter.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       5 region_file = "/home/jennifer/casa/M17_p2015/target2_region1.crtf"
#       7 # Crear instancia de FITSPlotter con la región CRTF
# ----> 8 plotter = FITSPlotter(image_fits=fits_file, region_file=region_file)
#      10 # Graficar la imagen recortada a la región del CRTF
#      11 plotter.plot()
#
# TypeError: FITSPlotter.__init__() got an unexpected keyword argument 'region_file'
