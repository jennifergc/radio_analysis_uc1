# %% [markdown]
# ### CALCULANDO CONTORNOS USANDO CASA EN PYTHON

# %%
import subprocess
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from astropy.io import fits
import pandas as pd


import sys
sys.path.append('/home/jennifer/fits_plotting_tool')
from fits_plotter2 import FITSPlotter

# %%
# Definir el comando para ejecutar CASA
cmd = [
    "/home/jennifer/casa/casa-6.6.5-31-py3.10.el8/bin/casa",
    "--nologger", "--nogui", "-c",
    "/home/jennifer/casa/M17_P2019/casa_contornos.py", "/home/jennifer/casa/M17_P2019/ALMA01480118_m0_nomask.fits", "0.007918", "15,17,19,21,23,27", "ALMA01480118_contours.fits"
]

# Ejecutar CASA en el sistema
subprocess.run(cmd)
# Out:
# optional configuration file not found, continuing CASA startup without it
#
# No event loop hook running.
# Using matplotlib backend: module://matplotlib_inline.backend_inline
# CASA 6.6.5.31 -- Common Astronomy Software Applications [6.6.5.31]
# CASA exits with a non-zero status : exception: <class 'IsADirectoryError'>
# Traceback (most recent call last):
#   File "/home/jennifer/.local/lib/python3.10/site-packages/casashell/private/init_system.py", line 275, in __evprop__
#     run_path( args[0], init_globals=exec_globals, run_name='__main__' )
#   File "/home/jennifer/casa/casa-6.6.5-31-py3.10.el8/lib/py/lib/python3.10/runpy.py", line 289, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "/home/jennifer/casa/casa-6.6.5-31-py3.10.el8/lib/py/lib/python3.10/runpy.py", line 96, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# Cargar el archivo FITS
fits_file = "ALMA01480118_contours.fits"  # Asegúrate de que el nombre es correcto
hdu = fits.open(fits_file)
data = hdu[0].data  # Extraer datos de la imagen

# Verificar las dimensiones
print("Dimensiones originales del FITS:", data.shape)

# Si la imagen tiene más de 2 dimensiones, reduce la matriz
data = np.squeeze(data)  # Elimina dimensiones de tamaño 1

print("Dimensiones después de squeeze:", data.shape)

# Verifica que ahora tenga solo 2 dimensiones
if data.ndim != 2:
    raise ValueError(f"La imagen sigue teniendo {data.ndim} dimensiones, verifica el archivo FITS.")

# Graficar la imagen con contornos
plt.figure(figsize=(8, 6))
#plt.imshow(data, origin='lower', cmap='gray')  # Muestra la imagen en escala de grises
#plt.colorbar(label="Intensidad")  # Barra de color
plt.contour(data, levels=10, colors='red')  # Agrega contornos en rojo
plt.xlabel("Pixels X")
plt.ylabel("Pixels Y")
plt.title("Contornos de la imagen FITS")
plt.show()

# Cerrar el archivo FITS
hdu.close()
# Out:
# Dimensiones originales del FITS: (1, 1, 392, 472)
# Dimensiones después de squeeze: (392, 472)

# %%
#Una del continuo de la región
#fits_file = "/home/jennifer/casa/M17_P2019/ALMA01507446_region_plot.fits"
fits_file = "ALMA01480118_contours.fits"
#fits_file = "/home/jennifer/casa/M17_p2015/ALMB00094768_contour.png"
plotter = FITSPlotter(image_fits=fits_file)
plotter.plot(title="")
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58776.995884 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -67.754929 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -23.022886 from OBSGEO-[XYZ].
# Set OBSGEO-H to     5053.796 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
